# %% [markdown]
# #WEB SCRAPING: INITIAL STEPS

# %% [markdown]
# **Import libraries.**

# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd

# %% [markdown]
# **Send request and get response.**

# %%
url = "https://www.fda.gov/drugs/drug-safety-and-availability/drug-recalls"
response = requests.get(url)

# %% [markdown]
# **Inspect the response.**

# %%
#get the status code
response.status_code

# %%
#get the response text
response.text

# %%
response.content

# %% [markdown]
# **Parse the response with Beautiful Soup.**

# %%
soup = BeautifulSoup(response.content, 'html.parser')
print(soup.title.text) #test
# Out:
# Drug Recalls | FDA

# %% [markdown]
# **To view HTML in a better way...**

# %%
#use prettify
print(soup.prettify())

# %% [markdown]
# #WEB SCRAPING: EXTRAPOLATING THE FULL TABLE

# %% [markdown]
# **Create a dataframe of the full table.**

# %%
target_table = soup.find_all("table", attrs={"id": "datatable"})
target_table

# %%
#Create the header/column names
full_table = target_table[0]
rows = full_table.find_all("tr")
head_row = rows[0] 
other_rows = rows[1:] 

#Loop through all header elements, convert them to text, and strip/remove "\n"
#and then append to create an empty list with headers defined
headings = []
for item in head_row.find_all("th"): 
    item = (item.text).rstrip("\n")
    headings.append(item)
print(headings)
# Out:
# ['Date ', 'Brand Name(s) ', 'Product Description ', 'Recall Reason Description', 'Company Name ', 'Terminated Recall', 'Excerpt']

# %%
#Next, fill in the rows with the info by looping through all the entries
#and removing tags, \xa0 and \n and comma from the text
all_rows = [] 
for row_num in range(len(other_rows)): 
    row = [] 
    for row_item in other_rows[row_num].find_all("td"): 
        aa = re.sub("(\xa0)|(\n)|,","",row_item.text)
        row.append(aa)

    all_rows.append(row)

# %%
#Create the full table
df = pd.DataFrame(data=all_rows,columns=headings)
df.head()
# Out:
#         Date                       Brand Name(s)   \
# 0  04/12/2022                             Mylan
# 1  04/01/2022       Mickey Mouse The Mandalorian
# 2  04/01/2022  F&S Medical Supply dba Pink Toyz
# 3  03/30/2022                              Suave
# 4  03/29/2022               Teva Pharmaceuticals
#
#                                 Product Description   \
# 0  Insulin Glargine (Insulin glargine-yfgn) Injec...
# 1                     Hand Sanitizer
# 2             Pink Pussycat Capsules
# 3           Aerosol Antiperspirants
# 4  IDArubicin Hydrochloride Injection USP        ...
#
#                            Recall Reason Description  \
# 0  Label may be missing on some vials            ...
# 1  Presence of Methanol in Mickey Mouse and Prese...
# 2              Undeclared Sildenafil
# 3        Elevated levels of benzene
# 4  Potential Particulate Matter (silica and iron ...
#
#                                        Company Name  Terminated Recall Excerpt
# 0  Mylan Pharmaceuticals Inc. a Viatris Company  ...
# 1  Best Brands Consumer Products Inc.            ...
# 2  F&S Medical Supply dba Pink Toyz
# 3                           Unilever
# 4               Teva Pharmaceuticals

# %%
#You can drop empty/unnecessary columns such as Terminated Recall and Excerpt to have a cleaner view
df.drop(columns=['Terminated Recall','Excerpt'])
# Out:
#         Date                        Brand Name(s)   \
# 0  04/12/2022                              Mylan
# 1  04/01/2022        Mickey Mouse The Mandalorian
# 2  04/01/2022   F&S Medical Supply dba Pink Toyz
# 3  03/30/2022                               Suave
# 4  03/29/2022                Teva Pharmaceuticals
# 5  03/24/2022               Major Pharmaceuticals
# 6  03/22/2022                              Sandoz
# 7  03/22/2022  Adamis Pharmaceuticals Corporation
# 8  03/22/2022          Accuretic Greenstone Brand
# 9  03/10/2022             Olympia Pharmaceuticals
#
#                                 Product Description   \
# 0  Insulin Glargine (Insulin glargine-yfgn) Injec...
# 1                     Hand Sanitizer
# 2             Pink Pussycat Capsules
# 3           Aerosol Antiperspirants
# 4  IDArubicin Hydrochloride Injection USP        ...
# 5  Magnesia Oral Suspension 2400 mg/30 mL Magnesi...
# 6  Orphenadrine Citrate 100 mg Extended Release (...
# 7  SYMJEPI (epinephrine) Injection 0.15 mg (0.15 ...
# 8  Accuretic™ (quinapril HCl/hydrochlorothiazide)...
# 9             Compounded Injectables
#
#                            Recall Reason Description  \
# 0  Label may be missing on some vials            ...
# 1  Presence of Methanol in Mickey Mouse and Prese...
# 2              Undeclared Sildenafil
# 3        Elevated levels of benzene
# 4  Potential Particulate Matter (silica and iron ...
# 5            Microbial Contamination
# 6  Presence of a Nitrosamine Impurity            ...
# 7  Potential clogging of the needle preventing th...
# 8  Presence of a nitrosamine N-nitroso-quinapril ...
# 9  Products are out of specification
#
#                                        Company Name
# 0  Mylan Pharmaceuticals Inc. a Viatris Company  ...
# 1  Best Brands Consumer Products Inc.            ...
# 2  F&S Medical Supply dba Pink Toyz
# 3                           Unilever
# 4               Teva Pharmaceuticals
# 5           Plastikon Healthcare LLC
# 6                        Sandoz Inc.
# 7  Adamis Pharmaceuticals Corporation            ...
# 8                            Pfizer
# 9                   Olympia Pharmacy

# %%
df.shape #(rows,columns)
#Notice that after dropping the two columns, it still shows we have 7 columns
#That's because it drops and NOT eliminate completely
# Out:
# (10, 7)

# %% [markdown]
# **Save the results.**

# %%
#save as Excel to Google Drive from Colab
from google.colab import drive
drive.mount('/gdrive')
df.to_excel("/gdrive/My Drive/WEB SCRAPING - FDA Drug Recalls Table.xlsx")
# Out:
# Mounted at /gdrive
